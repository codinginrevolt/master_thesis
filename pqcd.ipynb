# %%
import numpy as np
import matplotlib.pyplot as plt
from pqcd.pQCD import pQCD

# %%
X = np.linspace(1/2,2,100)
mu_grid = np.linspace(2.0,3,200)

# %%
n_cs2_arrays = []

for iteration in X:
    pQCD_temp = pQCD(iteration)
    n_temp  = np.vectorize(pQCD_temp.number_density)(mu_grid)/0.16 #nsat
    cs2_temp = np.vectorize(pQCD_temp.speed2)(mu_grid)
    X_temp = [n_temp,cs2_temp]
    n_cs2_arrays.append(X_temp)

n_cs2_arrays = np.asarray(n_cs2_arrays)

# %%
np.asarray(n_cs2_arrays).shape
# Out:
# (100, 2, 200)

# %%
np.asarray(n_cs2_arrays)[1][0]
# first index selects the X,
# second index selects n or cs2, 
# third index selects the elements
# Out:
# array([19.5604067 , 19.66238784, 19.76426598, 19.86613137, 19.9680683 ,
#        20.07015552, 20.17246657, 20.27507014, 20.37803038, 20.48140719,
#        20.5852565 , 20.68963053, 20.79457801, 20.90014442, 21.0063722 ,
#        21.11330095, 21.22096758, 21.32940653, 21.43864987, 21.54872753,
#        21.65966734, 21.77149524, 21.88423538, 21.99791022, 22.11254064,
#        22.22814606, 22.3447445 , 22.46235271, 22.58098622, 22.70065943,
#        22.82138568, 22.94317732, 23.06604577, 23.19000158, 23.31505448,
#        23.44121347, 23.56848682, 23.69688211, 23.82640635, 23.95706592,
#        24.08886671, 24.22181405, 24.35591283, 24.49116749, 24.62758207,
#        24.7651602 , 24.90390518, 25.04381996, 25.18490718, 25.3271692 ,
#        25.47060811, 25.61522575, 25.76102372, 25.90800342, 26.05616603,
#        26.20551258, 26.3560439 , 26.50776066, 26.66066342, 26.81475257,
#        26.9700284 , 27.12649107, 27.28414066, 27.44297712, 27.60300036,
#        27.76421018, 27.92660631, 28.09018843, 28.25495616, 28.42090906,
#        28.58804666, 28.75636842, 28.92587381, 29.09656222, 29.26843305,
#        29.44148567, 29.61571941, 29.79113362, 29.96772761, 30.14550069,
#        30.32445216, 30.50458134, 30.68588752, 30.86837   , 31.0520281 ,
#        31.23686113, 31.4228684 , 31.61004925, 31.79840303, 31.98792908,
#        32.17862677, 32.37049549, 32.56353464, 32.75774363, 32.95312191,
#        33.14966892, 33.34738414, 33.54626707, 33.74631722, 33.94753414,
#        34.14991738, 34.35346654, 34.55818122, 34.76406105, 34.97110569,
#        35.17931483, 35.38868816, 35.59922543, 35.81092639, 36.02379082,
#        36.23781853, 36.45300936, 36.66936315, 36.88687981, 37.10555923,
#        37.32540136, 37.54640615, 37.7685736 , 37.99190372, 38.21639654,
#        38.44205214, 38.66887059, 38.89685202, 39.12599657, 39.35630439,
#        39.58777568, 39.82041065, 40.05420954, 40.28917261, 40.52530014,
#        40.76259245, 41.00104986, 41.24067274, 41.48146146, 41.72341642,
#        41.96653806, 42.21082681, 42.45628314, 42.70290755, 42.95070055,
#        43.19966267, 43.44979447, 43.70109653, 43.95356943, 44.2072138 ,
#        44.46203028, 44.71801953, 44.97518221, 45.23351904, 45.49303071,
#        45.75371798, 46.01558159, 46.27862231, 46.54284094, 46.80823828,
#        47.07481517, 47.34257243, 47.61151095, 47.88163159, 48.15293524,
#        48.42542283, 48.69909528, 48.97395354, 49.24999855, 49.52723131,
#        49.8056528 , 50.08526404, 50.36606603, 50.64805982, 50.93124646,
#        51.21562702, 51.50120258, 51.78797422, 52.07594307, 52.36511024,
#        52.65547686, 52.94704409, 53.23981309, 53.53378503, 53.8289611 ,
#        54.1253425 , 54.42293044, 54.72172614, 55.02173085, 55.32294581,
#        55.62537228, 55.92901153, 56.23386484, 56.53993351, 56.84721885,
#        57.15572216, 57.46544477, 57.77638803, 58.08855327, 58.40194186,
#        58.71655516, 59.03239455, 59.34946141, 59.66775715, 59.98728316])

# %% [markdown]
# round n to integers
#
# ```
# n_values = data[:, 0, :]
# n_rounded = np.round(n_values).astype(int)
#
# c_count = 1
#
# cs2_sum = cs2[0]
#
# for i in range(n): #n is rounded
#
#     if i!=len(n)-1:
#
#         if n_i+1 = n_i:
#
#             cs2_sum += cs2[i+1]
#             c_count += 1
#
#         else:
#             cs2_bin.append(cs2_sum/cs2_count)
#
#             if cs2_count != 1:
#                 n_bin.append(n[i-1])
#
#             else:
#                 n_bin.append(n[i])
#
#             cs2_count = 1
#             cs2_sum = cs2[i+1]
#
#     else:
#         cs2_bin.append(cs2_sum/cs2_count)
#
#         if cs2_count !=1:
#             n_bin.append(n[i-1])
#         else:
#             n_bin.append(n[i])
#
#
# ```

# %%
n_test = n_cs2_arrays[1,0,:]
cs2_test = n_cs2_arrays[1,1,:]

n_rounded = np.round(n_test).astype(int)
cs2_count = 1
cs2_sum = cs2_test[0]
cs2_bin=[]
n_bin=[]

# %%
def append_bins(cs2_bin, n_bin, n_rounded, cs2_sum, cs2_count, i):
    cs2_bin.append(cs2_sum / cs2_count)
    if cs2_count != 1:
        n_bin.append(n_rounded[i - 1])
    else:
        n_bin.append(n_rounded[i])

# %%
for i in range(len(n_rounded)): #n is rounded

    if i!=len(n_rounded)-1:

        if n_rounded[i+1] == n_rounded[i]:
            cs2_sum += cs2_test[i+1]
            cs2_count += 1

        else:
            append_bins(cs2_bin, n_bin, n_rounded, cs2_sum, cs2_count, i)
            cs2_count = 1
            cs2_sum = cs2_test[i+1]

    else:
        append_bins(cs2_bin, n_bin, n_rounded, cs2_sum, cs2_count, i)

# %% [markdown]
# now loop over all X sets

# %%
mu_grid = np.linspace(2.0,3,100) #Grid in chemical potential in [GeV]

pQCD1 = pQCD(1/2) #X=1/2 
pQCD2 = pQCD(2) #X=2 

plt.fill_between(mu_grid,np.vectorize(pQCD1.pressure)(mu_grid),np.vectorize(pQCD2.pressure)(mu_grid))
plt.yscale('log')
plt.ylabel('Pressure p [GeV/fm$^3$]')
plt.xlabel('Chemical potential $\mu$ [GeV]')
plt.title('Partial N3LO QCD EoS with scale variation X = [1/2,2]')
plt.show()
