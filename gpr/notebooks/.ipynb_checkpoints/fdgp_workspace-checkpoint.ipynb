# %%
import sys
import os

current_dir = os.path.dirname(os.path.abspath(''))
others_path = os.path.join(current_dir, '..', 'gpr')

others_path = os.path.abspath(others_path)
if others_path not in sys.path:
    sys.path.append(others_path)

import numpy as np
import matplotlib.pyplot as plt

import eos
import kernels
import gaussianprocess
import finitedimensionalgp
import sampling as sam
import prepare_ceft as pc
import prepare_pqcd as pp
import anal_helpers as anal
from pqcd.pQCD import pQCD
from constants import get_phi


from pathlib import Path
notebook_dir = Path.cwd()

# %% [markdown]
# # load data

# %%
n_ceft, cs2_ceft, cs2_l, cs2_u = anal.get_ceft_cs2()

# %%
n_ceft, cs2_ceft, cs2_l, cs2_u = anal.get_ceft_cs2()
cs2_ceft_sigma = pc.CI_to_sigma(cs2_u-cs2_l)
cs2_hat, X_hat, sigma_hat, l_hat, alpha_hat = sam.get_hype_samples()
n_pqcd, cs2_pqcd = pp.get_pqcd(X_hat, size=400)
cs2_pqcd_sigma = np.zeros_like(cs2_pqcd)



indices = np.arange(0, len(n_ceft), 12)
n = np.concatenate((n_ceft[indices], n_pqcd))
cs2 = np.concatenate((cs2_ceft[indices], cs2_pqcd))
cs2_sigma = np.concatenate((cs2_ceft_sigma[indices], cs2_pqcd_sigma))

# %% [markdown]
# # gp stuff

# %%
kernel = kernels.Kernel('SE', sigma=sigma_hat, l=l_hat)

x_test = np.linspace(n_ceft[0], n_pqcd[-1], 400) # number density in nsat, starting val is ending val of n crust, ending val is default 10 nsat


gp = gaussianprocess.GP(kernel, get_phi(cs2_hat))
gp.fit(n, x_test, cs2, var_f = cs2_sigma, stabilise=True)

cs2_test, sig = gp.posterior(sampling=False)

# %%
plt.rcParams["font.family"] = "serif"

plt.plot(x_test, cs2_test[0], label=f'GPR prediction')
plt.plot(n, cs2, 'r.', markersize=5, label='Observations')
plt.fill_between(x_test.ravel(), cs2_test[0] - 1.96 * sig, cs2_test[0] + 1.96 * sig, alpha=0.3, color='lightblue')

for i in range(2):
    rng = np.random.default_rng()
    y = rng.multivariate_normal(mean=gp.mean_star, cov=gp.cov_star)
    plt.plot(x_test, y, color="black", alpha=0.2)

plt.xlabel('n [n_sat]')
plt.ylabel(r'$c_s^2$(n)')
plt.title(f"Normal GP \n l={l_hat:.3f}, sigma={sigma_hat:.3f}, cs2_hat={cs2_hat:.3f}, X_hat={X_hat:.3f}")

plt.legend()
plt.show()

# %%
m = 500

fdgp = finitedimensionalgp.FDGP(kernel, n, cs2, x_test, cs2_sigma, cs2_hat, True, m=m, sampling=False)
fdgp.fit()

# %%
knot_test_fdgp = (fdgp.knots * (fdgp.x_max - fdgp.x_min))+ fdgp.x_min

cs2_test_fdgp = fdgp.mean_star
sig_fdgp = np.sqrt(np.diag(fdgp.cov_star))

plt.rcParams["font.family"] = "serif"

plt.plot(knot_test_fdgp, cs2_test_fdgp, label=f'GPR prediction')
plt.plot(n, cs2, 'r.', markersize=5, label='Observations')
plt.fill_between(knot_test_fdgp.ravel(), cs2_test_fdgp - 1.96 * sig_fdgp, cs2_test_fdgp + 1.96 * sig_fdgp, alpha=0.3, color='lightblue')
plt.xlabel('n [n_sat]')
plt.ylabel(r'$c_s^2$(n)')
plt.title(f"l={l_hat:.3f}, sigma={sigma_hat:.3f}, cs2_hat={cs2_hat:.3f}, X_hat={X_hat:.3f}")
plt.title(fr"Finite Dimensional Approximation")

plt.legend()
plt.show()

# %%
knot_test_fdgp = (fdgp.knots * (fdgp.x_max - fdgp.x_min))+ fdgp.x_min

cs2_test_fdgp = fdgp.mean_star
sig_fdgp = np.sqrt(np.diag(fdgp.cov_star))

plt.rcParams["font.family"] = "serif"

for i in range(1):
    rng = np.random.default_rng()
    y = rng.multivariate_normal(mean=fdgp.mean_star, cov=fdgp.cov_star)
    plt.plot(knot_test_fdgp, y, color="black", alpha=0.2)

plt.plot(knot_test_fdgp, cs2_test_fdgp, label=f'FDGP mean prediction')
plt.plot(n, cs2, 'r.', markersize=5, label='Observations')
plt.fill_between(knot_test_fdgp.ravel(), cs2_test_fdgp - 1.96 * sig_fdgp, cs2_test_fdgp + 1.96 * sig_fdgp, alpha=0.3, color='lightblue')
plt.xlabel('n [n_sat]')
plt.ylabel(r'$c_s^2$(n)')
plt.title(f"l={l_hat:.3f}, sigma={sigma_hat:.3f}, cs2_hat={cs2_hat:.3f}, X_hat={X_hat:.3f}")
plt.title(fr"Finite Dimensional Approximation \n Unconstrainted with 10000 knots")

plt.legend()
plt.show()

# %%
constr = fdgp.set_constraints(fdgp.m, constraint_type='boundedness', l = 0, u=1, rm_inf=True)

constr_cs2 = fdgp.compute_MAP()
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -1346018252.1825042
#             Iterations: 1
#             Function evaluations: 1
#             Gradient evaluations: 1

# %%
plt.plot(knot_test_fdgp, constr_cs2, label='FDGP MAP')
plt.plot(n, cs2, 'r.', markersize=5, label='Observations')
plt.xlabel('n [n_sat]')
plt.ylabel(r'$c_s^2$(n)')
plt.title("Constrained FDGP")
plt.legend()
plt.show()

# %%
samples = fdgp.sample_posterior(5,return_trace=False)

# %%
asdfgasgfan
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 asdfgasgfan
#
# NameError: name 'asdfgasgfan' is not defined

# %%
fdgp.sample_posterior(100,return_trace=False)
# Out:
# array([[0.00923736, 0.01331761, 0.01809397, ..., 0.3215115 , 0.32159334,
#         0.32155069],
#        [0.00898915, 0.01329571, 0.01804265, ..., 0.32147716, 0.32140601,
#         0.32156927],
#        [0.00932484, 0.01342219, 0.01788465, ..., 0.32160529, 0.32153944,
#         0.32140504],
#        ...,
#        [0.00960104, 0.01400081, 0.018257  , ..., 0.32146683, 0.32163054,
#         0.32165194],
#        [0.00953683, 0.01375693, 0.01801133, ..., 0.32165754, 0.3215259 ,
#         0.32172162],
#        [0.00840344, 0.01212573, 0.0172387 , ..., 0.32168654, 0.32163059,
#         0.32159645]])

# %%
cs2_constrained = np.asarray([sum(samples[i][j] * fdgp._phi_j(j, fdgp.x_test[:,None]) for j in range(fdgp.m)) for i in range(0,samples.shape[0])])

# %%
x_test_fdgp = (fdgp.x_test * (fdgp.x_max - fdgp.x_min)) + fdgp.x_min

# %%
plt.plot(knot_test_fdgp, constr_cs2, label='FDGP MAP')
for i in range(0, samples.shape[0]):
    plt.plot(x_test_fdgp, cs2_constrained[i], alpha = 0.5)
#plt.plot(n, cs2, 'r.', markersize=5, label='Observations')
plt.xlabel('n [n_sat]')
plt.ylabel(r'$c_s^2$(n)')
plt.title("Constrained FDGP")
plt.legend()
plt.show()

# %%
for i in range(0, samples.shape[0]):
    plt.plot(knot_test_fdgp, constr_cs2, label='FDGP MAP')
    plt.plot(x_test_fdgp, cs2_constrained[i], alpha = 0.5, label='Constrained Sample')
    plt.xlabel('n [n_sat]')
    plt.ylabel(r'$c_s^2$(n)')
    plt.title("Constrained FDGP")
    plt.legend()
    plt.show()
#plt.plot(n, cs2, 'r.', markersize=5, label='Observations')

# %%
fdgp.knots
# Out:
# array([0.        , 0.00200401, 0.00400802, 0.00601202, 0.00801603,
#        0.01002004, 0.01202405, 0.01402806, 0.01603206, 0.01803607,
#        0.02004008, 0.02204409, 0.0240481 , 0.0260521 , 0.02805611,
#        0.03006012, 0.03206413, 0.03406814, 0.03607214, 0.03807615,
#        0.04008016, 0.04208417, 0.04408818, 0.04609218, 0.04809619,
#        0.0501002 , 0.05210421, 0.05410822, 0.05611222, 0.05811623,
#        0.06012024, 0.06212425, 0.06412826, 0.06613226, 0.06813627,
#        0.07014028, 0.07214429, 0.0741483 , 0.0761523 , 0.07815631,
#        0.08016032, 0.08216433, 0.08416834, 0.08617234, 0.08817635,
#        0.09018036, 0.09218437, 0.09418838, 0.09619238, 0.09819639,
#        0.1002004 , 0.10220441, 0.10420842, 0.10621242, 0.10821643,
#        0.11022044, 0.11222445, 0.11422846, 0.11623246, 0.11823647,
#        0.12024048, 0.12224449, 0.1242485 , 0.12625251, 0.12825651,
#        0.13026052, 0.13226453, 0.13426854, 0.13627255, 0.13827655,
#        0.14028056, 0.14228457, 0.14428858, 0.14629259, 0.14829659,
#        0.1503006 , 0.15230461, 0.15430862, 0.15631263, 0.15831663,
#        0.16032064, 0.16232465, 0.16432866, 0.16633267, 0.16833667,
#        0.17034068, 0.17234469, 0.1743487 , 0.17635271, 0.17835671,
#        0.18036072, 0.18236473, 0.18436874, 0.18637275, 0.18837675,
#        0.19038076, 0.19238477, 0.19438878, 0.19639279, 0.19839679,
#        0.2004008 , 0.20240481, 0.20440882, 0.20641283, 0.20841683,
#        0.21042084, 0.21242485, 0.21442886, 0.21643287, 0.21843687,
#        0.22044088, 0.22244489, 0.2244489 , 0.22645291, 0.22845691,
#        0.23046092, 0.23246493, 0.23446894, 0.23647295, 0.23847695,
#        0.24048096, 0.24248497, 0.24448898, 0.24649299, 0.24849699,
#        0.250501  , 0.25250501, 0.25450902, 0.25651303, 0.25851703,
#        0.26052104, 0.26252505, 0.26452906, 0.26653307, 0.26853707,
#        0.27054108, 0.27254509, 0.2745491 , 0.27655311, 0.27855711,
#        0.28056112, 0.28256513, 0.28456914, 0.28657315, 0.28857715,
#        0.29058116, 0.29258517, 0.29458918, 0.29659319, 0.29859719,
#        0.3006012 , 0.30260521, 0.30460922, 0.30661323, 0.30861723,
#        0.31062124, 0.31262525, 0.31462926, 0.31663327, 0.31863727,
#        0.32064128, 0.32264529, 0.3246493 , 0.32665331, 0.32865731,
#        0.33066132, 0.33266533, 0.33466934, 0.33667335, 0.33867735,
#        0.34068136, 0.34268537, 0.34468938, 0.34669339, 0.34869739,
#        0.3507014 , 0.35270541, 0.35470942, 0.35671343, 0.35871743,
#        0.36072144, 0.36272545, 0.36472946, 0.36673347, 0.36873747,
#        0.37074148, 0.37274549, 0.3747495 , 0.37675351, 0.37875752,
#        0.38076152, 0.38276553, 0.38476954, 0.38677355, 0.38877756,
#        0.39078156, 0.39278557, 0.39478958, 0.39679359, 0.3987976 ,
#        0.4008016 , 0.40280561, 0.40480962, 0.40681363, 0.40881764,
#        0.41082164, 0.41282565, 0.41482966, 0.41683367, 0.41883768,
#        0.42084168, 0.42284569, 0.4248497 , 0.42685371, 0.42885772,
#        0.43086172, 0.43286573, 0.43486974, 0.43687375, 0.43887776,
#        0.44088176, 0.44288577, 0.44488978, 0.44689379, 0.4488978 ,
#        0.4509018 , 0.45290581, 0.45490982, 0.45691383, 0.45891784,
#        0.46092184, 0.46292585, 0.46492986, 0.46693387, 0.46893788,
#        0.47094188, 0.47294589, 0.4749499 , 0.47695391, 0.47895792,
#        0.48096192, 0.48296593, 0.48496994, 0.48697395, 0.48897796,
#        0.49098196, 0.49298597, 0.49498998, 0.49699399, 0.498998  ,
#        0.501002  , 0.50300601, 0.50501002, 0.50701403, 0.50901804,
#        0.51102204, 0.51302605, 0.51503006, 0.51703407, 0.51903808,
#        0.52104208, 0.52304609, 0.5250501 , 0.52705411, 0.52905812,
#        0.53106212, 0.53306613, 0.53507014, 0.53707415, 0.53907816,
#        0.54108216, 0.54308617, 0.54509018, 0.54709419, 0.5490982 ,
#        0.5511022 , 0.55310621, 0.55511022, 0.55711423, 0.55911824,
#        0.56112224, 0.56312625, 0.56513026, 0.56713427, 0.56913828,
#        0.57114228, 0.57314629, 0.5751503 , 0.57715431, 0.57915832,
#        0.58116232, 0.58316633, 0.58517034, 0.58717435, 0.58917836,
#        0.59118236, 0.59318637, 0.59519038, 0.59719439, 0.5991984 ,
#        0.6012024 , 0.60320641, 0.60521042, 0.60721443, 0.60921844,
#        0.61122244, 0.61322645, 0.61523046, 0.61723447, 0.61923848,
#        0.62124248, 0.62324649, 0.6252505 , 0.62725451, 0.62925852,
#        0.63126253, 0.63326653, 0.63527054, 0.63727455, 0.63927856,
#        0.64128257, 0.64328657, 0.64529058, 0.64729459, 0.6492986 ,
#        0.65130261, 0.65330661, 0.65531062, 0.65731463, 0.65931864,
#        0.66132265, 0.66332665, 0.66533066, 0.66733467, 0.66933868,
#        0.67134269, 0.67334669, 0.6753507 , 0.67735471, 0.67935872,
#        0.68136273, 0.68336673, 0.68537074, 0.68737475, 0.68937876,
#        0.69138277, 0.69338677, 0.69539078, 0.69739479, 0.6993988 ,
#        0.70140281, 0.70340681, 0.70541082, 0.70741483, 0.70941884,
#        0.71142285, 0.71342685, 0.71543086, 0.71743487, 0.71943888,
#        0.72144289, 0.72344689, 0.7254509 , 0.72745491, 0.72945892,
#        0.73146293, 0.73346693, 0.73547094, 0.73747495, 0.73947896,
#        0.74148297, 0.74348697, 0.74549098, 0.74749499, 0.749499  ,
#        0.75150301, 0.75350701, 0.75551102, 0.75751503, 0.75951904,
#        0.76152305, 0.76352705, 0.76553106, 0.76753507, 0.76953908,
#        0.77154309, 0.77354709, 0.7755511 , 0.77755511, 0.77955912,
#        0.78156313, 0.78356713, 0.78557114, 0.78757515, 0.78957916,
#        0.79158317, 0.79358717, 0.79559118, 0.79759519, 0.7995992 ,
#        0.80160321, 0.80360721, 0.80561122, 0.80761523, 0.80961924,
#        0.81162325, 0.81362725, 0.81563126, 0.81763527, 0.81963928,
#        0.82164329, 0.82364729, 0.8256513 , 0.82765531, 0.82965932,
#        0.83166333, 0.83366733, 0.83567134, 0.83767535, 0.83967936,
#        0.84168337, 0.84368737, 0.84569138, 0.84769539, 0.8496994 ,
#        0.85170341, 0.85370741, 0.85571142, 0.85771543, 0.85971944,
#        0.86172345, 0.86372745, 0.86573146, 0.86773547, 0.86973948,
#        0.87174349, 0.87374749, 0.8757515 , 0.87775551, 0.87975952,
#        0.88176353, 0.88376754, 0.88577154, 0.88777555, 0.88977956,
#        0.89178357, 0.89378758, 0.89579158, 0.89779559, 0.8997996 ,
#        0.90180361, 0.90380762, 0.90581162, 0.90781563, 0.90981964,
#        0.91182365, 0.91382766, 0.91583166, 0.91783567, 0.91983968,
#        0.92184369, 0.9238477 , 0.9258517 , 0.92785571, 0.92985972,
#        0.93186373, 0.93386774, 0.93587174, 0.93787575, 0.93987976,
#        0.94188377, 0.94388778, 0.94589178, 0.94789579, 0.9498998 ,
#        0.95190381, 0.95390782, 0.95591182, 0.95791583, 0.95991984,
#        0.96192385, 0.96392786, 0.96593186, 0.96793587, 0.96993988,
#        0.97194389, 0.9739479 , 0.9759519 , 0.97795591, 0.97995992,
#        0.98196393, 0.98396794, 0.98597194, 0.98797595, 0.98997996,
#        0.99198397, 0.99398798, 0.99599198, 0.99799599, 1.        ])

# %% [markdown]
# 606 knots in total
#
# when placed uniformly,
#
# 606 knots span about 40 n_s uniformly, so about 15 knots per 1n_s
#
# this means that there are only ~30 knots in chiral eft band
#
# while (40-25)*15 = 225 knots there

# %% [markdown]
# so in terms of datapoints, ceft we have 102 datapoints and 30 knots
#
# we have for pqcd, we have 100 points and 225 knots

# %% [markdown]
# when pqcd gets wiggly, hmc takes fucking forever

# %% [markdown]
# # knots placement

# %% [markdown]
# 200 obs in pQCD between 25 and 400, that is 13 obs per nsat
#
# 175 in ChEFT, that is close to 100 obs per nsat
#
# instead us 80 obs between crust and 2ns

# %%
def smooth_spacing(x, delta_low, delta_high, center, width, strength=1):
    """
    Smooth interpolation between delta_low and delta_high centered at 'center',
    with a transition width defined by 'width'.
    """
    sigmoid = 1 / (1 + np.exp(- (x - center) * strength / width))
    return delta_low + (delta_high - delta_low) * sigmoid

# %%
def generate_custom_knots_by_count(
    n1, n2, n3,
    transition_width=1.0,
    region1=(0.47375, 2),
    trans1=(2, 3),
    region2=(3, 24),
    trans2=(24, 25),
    region3=(25, 40)
):
    knots = []

    # Compute uniform spacing for each region
    delta1 = (region1[1] - region1[0]) / (n1 - 1)
    delta2 = (region2[1] - region2[0]) / (n2 - 1)
    delta3 = (region3[1] - region3[0]) / (n3 - 1)

    # Region 1: Uniform Δm₁
    x = np.linspace(region1[0], region1[1], n1)
    knots.append(x)

    # Transition 1: Smooth Δm from Δm₁ → Δm₂
    x = [region1[1]]
    while x[-1] < trans1[1]:
        dx = smooth_spacing(x[-1], delta1, delta2, center=np.mean(trans1), width=transition_width)
        next_knot = x[-1] + dx
        x.append(next_knot)
    knots.append(np.array(x[1:]))

    # Region 2: Uniform Δm₂
    x = np.linspace(region2[0], region2[1], n2)
    knots.append(x)

    # Transition 2: Smooth Δm from Δm₂ → Δm₃
    x = [region2[1]]
    while x[-1] < trans2[1]:
        dx = smooth_spacing(x[-1], delta2, delta3, center=np.mean(trans2), width=transition_width)
        next_knot = x[-1] + dx
        x.append(next_knot)
    knots.append(np.array(x[:-1]))

    # Region 3: Uniform Δm₃
    x = np.linspace(region3[0], region3[1], n3)
    knots.append(x)

    return np.unique(np.concatenate(knots))

# %%
# Generate the custom knots
knots = generate_custom_knots_by_count(175,200,400, transition_width=0.1)

# Compute spacing (Δm) between knots
spacing = np.diff(knots)

# Plot the knots as vertical lines
plt.figure(figsize=(12, 3))
plt.vlines(knots, ymin=0, ymax=1, colors='black', alpha=0.5, linewidth=0.8)
plt.title("Knots Distribution with Smooth Transitions")
plt.xlabel("x")
plt.yticks([])
plt.grid(True)

# Optional: highlight transition regions
for region in [(2, 3), (24, 25)]:
    plt.axvspan(region[0], region[1], color='orange', alpha=0.2, label='Transition' if region == (2, 3) else None)

plt.legend()
plt.tight_layout()
plt.show()

# Plot the spacing between knots
plt.figure(figsize=(12, 3))
plt.plot(knots[:-1], spacing, marker='o', markersize=2, linestyle='-', linewidth=0.7)
plt.title("Spacing Δm Between Knots")
plt.xlabel("x")
plt.ylabel("Δm")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # fdgp with custom knots

# %%
knot = generate_custom_knots_by_count(175,200,400, transition_width=0.1)

kernel = kernels.Kernel('SE', sigma=sigma_hat, l=l_hat)
x_test = np.linspace(n_ceft[0], n_pqcd[-1], 400) # number density in nsat, starting val is ending val of n crust, ending val is default 10 nsat

fdgp = finitedimensionalgp.FDGP(kernel, n, cs2, x_test, cs2_sigma, cs2_hat, True, knots=knot, sampling=False)
fdgp.fit()
# Out:
# (0,)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       3 kernel = kernels.Kernel('SE', sigma=sigma_hat, l=l_hat)
#       4 x_test = np.linspace(n_ceft[0], n_pqcd[-1], 400) # number density in nsat, starting val is ending val of n crust, ending val is default 10 nsat
# ----> 6 fdgp = finitedimensionalgp.FDGP(kernel, n, cs2, x_test, cs2_sigma, cs2_hat, True, knots=knot, sampling=False)
#       7 fdgp.fit()
#
# File ~/thesis/code/gpr/finitedimensionalgp.py:67, in FDGP.__init__(self, kernel, x_train, y_train, x_test, var_y, prior_mean, stabilise, jitter_value, m, knots, sampling)
#      64 self.js = np.arange(0, m, 1)
#      66 print(self.js.shape)
# ---> 67 breakpoint(self.m)
#      68 self.Gamma = self.kernel.compute(self.knots)
#      69 self.Phi_matrix = self._phi_j(self.js[None,:], self.x_train[:,None])
#
# TypeError: debugpy_breakpointhook() takes 0 positional arguments but 1 was given

# %%
knot_test_fdgp = (fdgp.knots * (fdgp.x_max - fdgp.x_min))+ fdgp.x_min

cs2_test_fdgp = fdgp.mean_star
sig_fdgp = np.sqrt(np.diag(fdgp.cov_star))

plt.rcParams["font.family"] = "serif"

for i in range(1):
    rng = np.random.default_rng()
    y = rng.multivariate_normal(mean=fdgp.mean_star, cov=fdgp.cov_star)
    plt.plot(knot_test_fdgp, y, color="black", alpha=0.2)

plt.plot(knot_test_fdgp, cs2_test_fdgp, label=f'FDGP mean prediction')
plt.plot(n, cs2, 'r.', markersize=5, label='Observations')
plt.fill_between(knot_test_fdgp.ravel(), cs2_test_fdgp - 1.96 * sig_fdgp, cs2_test_fdgp + 1.96 * sig_fdgp, alpha=0.3, color='lightblue')
plt.xlabel('n [n_sat]')
plt.ylabel(r'$c_s^2$(n)')
plt.title(f"l={l_hat:.3f}, sigma={sigma_hat:.3f}, cs2_hat={cs2_hat:.3f}, X_hat={X_hat:.3f}")
plt.title(fr"Finite Dimensional Approximation \n Unconstrainted with 10000 knots")

plt.legend()
plt.show()
