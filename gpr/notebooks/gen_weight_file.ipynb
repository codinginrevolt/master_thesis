# %%
import numpy as np

from pathlib import Path
notebook_dir = Path.cwd()

# %%
n_eos = 20000

file_path = notebook_dir.parent.parent / f'results/tov_res'

# %%
weight = 1e-4

data = np.full((n_eos,), weight)

np.savetxt(file_path/"eos_weights", data)

print("File created")
# Out:
# File created
